# %%
import pandas as pd
import numpy as np
import re
from transformers import pipeline
from transformers import AutoTokenizer

# %%
df = pd.read_json('/content/train.json')

# %%
# Removing outliers (filtering prices over the 99.9th percentile)
upper_bound = np.percentile(df["price"].values, 99.9)
df_filtered = df[df["price"] <= upper_bound]

# %%
# Preprocess descriptions (remove HTML tags, convert to lowercase)
def remove_html_tags(description):
    description = re.sub(r'<[^>]+>', '', description)
    description = re.sub(r'\s+', ' ', description)
    return description.strip()

# %%
df_filtered["description"] = df_filtered["description"].apply(remove_html_tags)
df_filtered["description"] = df_filtered["description"].apply(lambda desc: desc.lower())
# Out:
# <ipython-input-5-d450e829771d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["description"] = df_filtered["description"].apply(remove_html_tags)
# <ipython-input-5-d450e829771d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["description"] = df_filtered["description"].apply(lambda desc: desc.lower())

# %%
# Tokenizer initialization (using distilBERT model)
tokenizer = AutoTokenizer.from_pretrained('distilbert-base-uncased')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
# Function to truncate text to fit the model input size
def truncate_text(text, max_length=512):
    if not text.strip():  # Check if the text is empty after removing spaces
        return " "
    inputs = tokenizer.encode_plus(
        text,
        add_special_tokens=True,
        max_length=max_length,
        truncation=True
    )
    truncated_text = tokenizer.decode(inputs['input_ids'], skip_special_tokens=True)
    return truncated_text

# %%
# Truncate descriptions
df_filtered['truncated_description'] = df_filtered['description'].apply(truncate_text)
# Out:
# <ipython-input-8-17fc53574e05>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['truncated_description'] = df_filtered['description'].apply(truncate_text)

# %%
# Initialize sentiment analysis pipeline
sentiment_pipeline = pipeline("sentiment-analysis", device=0)  # Using GPU if available
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
# Batch processing function
def get_sentiment_batch(texts):
    return sentiment_pipeline(texts)

# %%
# Set batch size for processing
batch_size = 16  # Adjust batch size based on GPU memory

# %%
# Initialize a list to store the results
sentiments = []

# %%
# Process data in batches
for i in range(0, len(df_filtered), batch_size):
    batch = df_filtered['truncated_description'][i:i + batch_size].tolist()  # Convert to list for batch processing
    sentiments_batch = get_sentiment_batch(batch)
    sentiments.extend(sentiments_batch)  # Add the results to the list
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset

# %%
# Assign the results to the DataFrame
df_filtered['sentiment'] = sentiments
# Out:
# <ipython-input-14-047df4d9b354>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['sentiment'] = sentiments

# %%
# Sentiment classification function based on score thresholds
positive_threshold = 0.75
negative_threshold = 0.25

# %%
def classify_sentiment(sentiment):
    print(f"Processing sentiment: {sentiment}")  # Debugging line
    score = sentiment['score']
    if sentiment['label'] == 'POSITIVE' and score >= positive_threshold:
        return 1
    elif sentiment['label'] == 'NEGATIVE' and score <= negative_threshold:
        return -1
    elif sentiment['label'] == 'NEUTRAL':
        return 0  # Treat 'NEUTRAL' as 0
    else:
        return 0  # Default case for unexpected labels

# %%
# Apply sentiment classification
df_filtered['sentiment_label'] = df_filtered['sentiment'].apply(classify_sentiment)
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9985800981521606}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9986535310745239}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.5581045150756836}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9939087629318237}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996242523193359}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9946309328079224}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9943278431892395}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9932077527046204}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9992578625679016}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996932744979858}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9988749623298645}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9823254942893982}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994601607322693}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9928125739097595}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9949711561203003}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9993409514427185}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9987356066703796}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.8636193871498108}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9983141422271729}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.990818440914154}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9993414282798767}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995718598365784}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9979583024978638}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9694534540176392}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9990110397338867}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996846914291382}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9952223896980286}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9986282587051392}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9907515048980713}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9982367753982544}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9948345422744751}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9989559650421143}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9723614454269409}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.99847811460495}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994449019432068}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994189739227295}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9712751507759094}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9984947443008423}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.8976069092750549}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9993533492088318}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995986819267273}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9843605160713196}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9946051239967346}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997180104255676}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9993239641189575}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.6333935856819153}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9667385816574097}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.5241430997848511}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9911318421363831}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9591219425201416}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.998703122138977}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9984092116355896}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.99049311876297}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9769091010093689}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9945669174194336}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9989141225814819}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9974117875099182}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9998821020126343}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9987953901290894}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9799442291259766}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9911318421363831}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9988952279090881}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995253086090088}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.8796857595443726}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9911932349205017}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994297623634338}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9960324168205261}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9976732134819031}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9993938207626343}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997053742408752}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9956881403923035}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997372031211853}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9266995787620544}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9967165589332581}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9983295798301697}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9902604222297668}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9998373985290527}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9993782043457031}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9920251369476318}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9998223185539246}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9754241704940796}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9988609552383423}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9983957409858704}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9993966817855835}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9886364340782166}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9943189024925232}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9983248114585876}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.6839854121208191}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9993754029273987}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996987581253052}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.999295711517334}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.997295081615448}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9962577819824219}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997605681419373}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9971845746040344}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9973713159561157}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.5063779950141907}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.6535490155220032}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9960582256317139}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9961544871330261}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9982950091362}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9968910813331604}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9942194223403931}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994478821754456}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9628938436508179}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9911318421363831}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.999616265296936}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9863592982292175}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9982535243034363}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994499087333679}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9956236481666565}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9991024732589722}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.999036431312561}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.848444938659668}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9974550604820251}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9887443780899048}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9677683115005493}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9973949193954468}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9966917037963867}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.8037030696868896}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7621503472328186}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9854567646980286}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997033476829529}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994691014289856}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9946631193161011}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9266704320907593}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9991361498832703}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9482300281524658}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994839429855347}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.998887836933136}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9970115423202515}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9988308548927307}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995341300964355}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9961712956428528}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9991783499717712}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9957244396209717}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.8826985955238342}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.997484564781189}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9917401075363159}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9980033040046692}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9093284606933594}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9970937967300415}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9925544857978821}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9966164231300354}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9974391460418701}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9982841610908508}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9991233944892883}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.947346568107605}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9564500451087952}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9954845905303955}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9980996251106262}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9900998473167419}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995261430740356}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.8710307478904724}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9753096699714661}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.8241791129112244}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9998352527618408}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.5837059617042542}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995971322059631}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9954736828804016}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9981326460838318}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9990615248680115}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9979442954063416}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9923730492591858}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9946163296699524}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995798468589783}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9983933568000793}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997900128364563}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9986209869384766}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.6981127858161926}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9992638230323792}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.8910361528396606}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9990026354789734}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.998645007610321}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9843181371688843}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996005892753601}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9998306035995483}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9986000657081604}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997441172599792}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995003938674927}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9991075396537781}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9965171813964844}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.7357457876205444}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9980219602584839}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9839053750038147}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.8745686411857605}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9992520213127136}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.6900529265403748}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9863467812538147}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.999546468257904}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9960325360298157}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9427806735038757}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9992958307266235}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9964897036552429}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9974602460861206}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997876286506653}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9940057992935181}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9815019965171814}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9986100196838379}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9991129040718079}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.6606422066688538}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.848444938659668}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9646925926208496}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9928273558616638}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9919329285621643}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.86026531457901}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9977213740348816}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.8634577989578247}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9826183319091797}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995821118354797}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9992960691452026}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9963841438293457}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9840616583824158}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9927438497543335}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9910281300544739}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9993484616279602}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9966788291931152}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9971579313278198}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.6630758047103882}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9985028505325317}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9978601336479187}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.999743640422821}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9807778000831604}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995334148406982}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.999736487865448}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996211528778076}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9959613680839539}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.998261034488678}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9790408611297607}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9341452121734619}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9694828987121582}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997217059135437}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.8837357759475708}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9998294115066528}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997944235801697}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9984329342842102}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996726512908936}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9991353154182434}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995481371879578}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994012117385864}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9984989166259766}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996293783187866}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9985927939414978}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9993599057197571}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.8208504915237427}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.8865662217140198}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9998007416725159}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9998346567153931}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9978668093681335}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9770610928535461}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9985218644142151}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.981875479221344}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9939659237861633}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9963326454162598}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995337724685669}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9938045740127563}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9993714690208435}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9905608296394348}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9984049201011658}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9976783394813538}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.5345044136047363}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996836185455322}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9988498687744141}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996088147163391}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9805872440338135}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.975667417049408}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9972221851348877}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9988032579421997}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9954944849014282}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.6232914924621582}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996218681335449}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.993650496006012}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9998047947883606}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9773862361907959}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997209906578064}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9992838501930237}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9546176195144653}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9696741104125977}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9766150712966919}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997602105140686}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.99335116147995}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9956458210945129}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9969428181648254}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9781723022460938}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9982219338417053}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995176792144775}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9732608199119568}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9984937906265259}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9993228912353516}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9821894764900208}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9254207611083984}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.997038722038269}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.915837287902832}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9990614056587219}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9971573352813721}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997596144676208}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9940444827079773}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9821377992630005}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9981734752655029}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9895678162574768}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9991998076438904}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9990516304969788}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9991664886474609}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9988064765930176}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997124075889587}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9565070271492004}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.5579132437705994}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9897687435150146}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994603991508484}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.6120564341545105}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9936143755912781}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9549739956855774}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.998976469039917}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9992666840553284}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.999625563621521}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9975040555000305}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9998422861099243}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9983548521995544}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9983510971069336}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995928406715393}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9990200996398926}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994919300079346}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994509816169739}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9991208910942078}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995631575584412}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9955874681472778}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9998514652252197}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9973957538604736}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9857516884803772}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9988077878952026}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.998795747756958}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9702792167663574}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9949349761009216}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997861981391907}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9993959665298462}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9936074018478394}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996935129165649}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9749096632003784}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9101819396018982}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9737057089805603}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9984548091888428}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9711816906929016}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.8844361305236816}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9937323927879333}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9982032775878906}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.853890061378479}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.6185629367828369}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9977179765701294}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9912145137786865}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.99458247423172}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9851592183113098}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.999757707118988}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9987550973892212}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996979236602783}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.990740180015564}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9993359446525574}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9990221261978149}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9967369437217712}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994887113571167}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9556807279586792}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.848444938659668}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9516189098358154}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.992347002029419}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9728701710700989}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9992902278900146}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9222062826156616}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9754734039306641}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9973112344741821}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9972420930862427}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9980301260948181}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9963251948356628}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9911318421363831}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997337460517883}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9989653825759888}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7425061464309692}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9981496334075928}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.981633186340332}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.7131956219673157}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995416402816772}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.999103844165802}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9090205430984497}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.7685697078704834}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9746025800704956}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9980970025062561}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9749358296394348}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9828989505767822}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9970177412033081}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9963558912277222}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9989738464355469}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9966918230056763}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9913842678070068}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9986099004745483}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9972286820411682}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9926632642745972}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.99954754114151}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994064569473267}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9987527132034302}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9943785071372986}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9952337145805359}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9959791898727417}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9992480874061584}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996471405029297}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995951056480408}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9989141225814819}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994828701019287}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.999661922454834}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996707439422607}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9883334636688232}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995611310005188}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9983280301094055}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994761347770691}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9141260981559753}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9465056657791138}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9913541674613953}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9977796673774719}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.5429845452308655}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.998492956161499}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995588660240173}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9967659711837769}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.999461829662323}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9992209672927856}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9992899894714355}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996812343597412}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9680880904197693}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.659461259841919}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.990564227104187}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9572328925132751}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9131413698196411}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9755259156227112}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9959006905555725}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995009899139404}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997939467430115}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9987642765045166}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994451403617859}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9978469610214233}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995206594467163}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997480511665344}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.6648942828178406}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.998576283454895}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.5190982222557068}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9984779953956604}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995786547660828}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9824244379997253}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9992443323135376}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9976291060447693}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994650483131409}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994801878929138}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9968083500862122}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9961068034172058}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995230436325073}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9986218214035034}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996836185455322}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994687438011169}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996926784515381}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9602442979812622}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9929707646369934}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996421337127686}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9993246793746948}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9977794289588928}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9669568538665771}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995539784431458}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.8556938171386719}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9943450689315796}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9990707635879517}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9984644651412964}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9628183841705322}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.8614974021911621}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9949820637702942}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9991822838783264}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995461106300354}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9974952936172485}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9884400367736816}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996801614761353}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9984620809555054}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9984744191169739}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.8708540797233582}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995645880699158}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9992383718490601}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9937776327133179}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9984768033027649}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9991462230682373}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9972144961357117}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.8865788578987122}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996121525764465}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997667670249939}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9868898391723633}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.997104823589325}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.999259889125824}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.998480498790741}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9477084279060364}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9990540146827698}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9916337728500366}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994706511497498}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9873403906822205}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.999561607837677}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9557675123214722}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995706677436829}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9956145286560059}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.996514618396759}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997790455818176}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9797398447990417}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9989547729492188}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9975441098213196}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9986531734466553}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9951477646827698}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9984571933746338}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9990240335464478}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9910597205162048}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9949508905410767}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996283054351807}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9998067021369934}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.979465663433075}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9989579916000366}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9951477646827698}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9930845499038696}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9869727492332458}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9992964267730713}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9667567014694214}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9963645339012146}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9928606152534485}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996128678321838}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9982170462608337}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9876372814178467}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9919913411140442}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.999526858329773}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996784925460815}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9986061453819275}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9854058027267456}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9992735981941223}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9973146319389343}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9946631193161011}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9564154744148254}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.8466202616691589}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.993798553943634}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.8773185014724731}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9979771971702576}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.999263346195221}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995244741439819}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9993804693222046}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.6406211256980896}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9991940855979919}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9957600235939026}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9977130889892578}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.984782874584198}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9747375845909119}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9678331017494202}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9962557554244995}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9992125034332275}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9963674545288086}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9992703795433044}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9984536170959473}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9795589447021484}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9911060929298401}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9813734889030457}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9188838005065918}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9951230883598328}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9046593904495239}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997909665107727}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.99607253074646}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9969507455825806}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9993983507156372}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997510313987732}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9974972605705261}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9983875751495361}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9880954027175903}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9988823533058167}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9991453886032104}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9989707469940186}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.8248411417007446}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9877645373344421}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9968042373657227}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996438026428223}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9704515933990479}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9912124276161194}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9714784026145935}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9887621998786926}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9403823018074036}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9835734963417053}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.996185839176178}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996346235275269}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9991165995597839}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9994074106216431}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9991956353187561}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9721859097480774}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.5445631742477417}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9911318421363831}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996008276939392}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9258702993392944}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995730519294739}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996836185455322}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9987583160400391}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9891465902328491}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9942309856414795}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9928515553474426}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9735983610153198}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994783997535706}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.99897301197052}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9715389013290405}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9962865114212036}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9974628686904907}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9989848732948303}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.997028648853302}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9964953064918518}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9916751384735107}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.7148340344429016}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.8242233395576477}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995088577270508}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.94521164894104}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9779441952705383}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996305704116821}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9978650212287903}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9965978264808655}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9992852807044983}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9987241625785828}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.986889123916626}
# ...
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9986461997032166}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996178150177002}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9669705629348755}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9943760633468628}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.8843204379081726}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995635151863098}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9985407590866089}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9439473152160645}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.954537570476532}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994982481002808}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9387555718421936}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9945730566978455}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997125267982483}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9976298809051514}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.999402642250061}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9991875290870667}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9982376098632812}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9984708428382874}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.999339759349823}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995542168617249}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996213912963867}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995008707046509}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9969671368598938}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9971694350242615}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9799846410751343}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.996561586856842}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9796718955039978}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9856647253036499}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9984514713287354}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997807145118713}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997885823249817}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9230536222457886}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996151924133301}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9911318421363831}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994587302207947}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9812244176864624}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9955515265464783}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997264742851257}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9836808443069458}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994971752166748}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9147512912750244}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996114373207092}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.99522864818573}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.999211311340332}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9302639961242676}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.8838164806365967}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9935433864593506}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9976978898048401}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9948693513870239}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9969661831855774}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9980564117431641}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.992529571056366}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997493624687195}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995267391204834}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9985373020172119}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9980021119117737}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9986891150474548}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997842907905579}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9973282814025879}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9998606443405151}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9998266100883484}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9072786569595337}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9992127418518066}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9936989545822144}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9961994290351868}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9988340735435486}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9992246627807617}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996627569198608}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9792256355285645}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9938386082649231}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.996659517288208}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9900420904159546}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9964708089828491}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9870822429656982}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9992203712463379}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9672183394432068}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995697140693665}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9853845238685608}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996434450149536}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9815250635147095}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9873752593994141}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994450211524963}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9984869956970215}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9938832521438599}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.998675525188446}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9604611396789551}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9958000779151917}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.996489942073822}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.5473677515983582}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9449918866157532}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9991305470466614}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9965325593948364}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9964549541473389}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9944191575050354}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9989479184150696}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.991898775100708}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.8006336092948914}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996243715286255}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9988982677459717}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9990838766098022}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9930620789527893}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9992691874504089}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9809679388999939}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.8870032429695129}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7554174065589905}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9478166699409485}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9991676807403564}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9912171363830566}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9970730543136597}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9958059787750244}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.5177196264266968}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9958385229110718}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9968042373657227}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9974870681762695}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9986799359321594}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.967507004737854}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995129108428955}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9702541828155518}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9827176928520203}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9509528279304504}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9951230883598328}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9982466697692871}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9600525498390198}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.693647563457489}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997982382774353}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9953065514564514}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9682696461677551}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9988923668861389}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.991630494594574}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.982585072517395}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994713664054871}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9951955676078796}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994614720344543}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9403706192970276}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9766854643821716}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9938132762908936}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994959831237793}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9938767552375793}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9626986980438232}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994064569473267}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996974468231201}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995719790458679}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9976248145103455}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.999504566192627}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.897665798664093}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9889370203018188}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9974833130836487}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9934693574905396}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9991416931152344}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9582036137580872}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.8371050357818604}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9993734955787659}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.8947707414627075}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9988271594047546}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.993751585483551}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9726114273071289}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9979450106620789}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9982768297195435}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9900736808776855}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996706247329712}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.9779115319252014}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9990856647491455}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996040463447571}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9812807440757751}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9988654851913452}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.6097921133041382}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9973216652870178}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9928085803985596}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.999832034111023}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.7481212019920349}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.999713122844696}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9158142805099487}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9839547872543335}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994240999221802}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9994634985923767}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.8989483118057251}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9982743263244629}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997115731239319}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9898009896278381}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9996259212493896}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9997937083244324}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9995825886726379}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.5807931423187256}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9989222288131714}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9938253164291382}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9967396855354309}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9927777647972107}
# Processing sentiment: {'label': 'NEGATIVE', 'score': 0.7529003024101257}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9972987771034241}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9958628416061401}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9989745616912842}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.8025766611099243}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9993302822113037}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9970218539237976}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9568416476249695}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.8604073524475098}
# Processing sentiment: {'label': 'POSITIVE', 'score': 0.9954116940498352}
# <ipython-input-17-133af390e600>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['sentiment_label'] = df_filtered['sentiment'].apply(classify_sentiment)

# %%
# Display the first few rows to check the result
df_filtered.head(5)
# Out:
#     bathrooms  bedrooms                       building_id  \
# 4         1.0         1  8579a0b0d54db803821a35a4a615e97a
# 6         1.0         2  b8e75fc949a6cd8225b455648a951712
# 9         1.0         2  cd759a988b8f23924b5a2058d5ab2b49
# 10        1.5         3  53a5b119ba8f7b61d4e010512e0dfc85
# 15        1.0         0  bfb9405149bfff42a92980b594c28234
#
#                 created                                        description  \
# 4   2016-06-16 05:55:27  spacious 1 bedroom 1 bathroom in williamsburg!...
# 6   2016-06-01 05:44:33  brand new gut renovated true 2 bedroomfind you...
# 9   2016-06-14 15:19:59  **flex 2 bedroom with full pressurized wall**l...
# 10  2016-06-24 07:54:24  a brand new 3 bedroom 1.5 bath apartmentenjoy ...
# 15  2016-06-28 03:50:23  over-sized studio w abundant closets. availabl...
#
#         display_address                                           features  \
# 4   145 Borinquen Place  [Dining Room, Pre-War, Laundry in Building, Di...
# 6             East 44th  [Doorman, Elevator, Laundry in Building, Dishw...
# 9      East 56th Street  [Doorman, Elevator, Laundry in Building, Laund...
# 10  Metropolitan Avenue                                                 []
# 15     East 34th Street  [Doorman, Elevator, Fitness Center, Laundry in...
#
#     latitude  listing_id  longitude                        manager_id  \
# 4    40.7108     7170325   -73.9539  a10db4590843d78c784171a107bdacb4
# 6    40.7513     7092344   -73.9722  955db33477af4f40004820b4aed804a0
# 9    40.7575     7158677   -73.9625  c8b10a317b766204f08e613cef4ce7a0
# 10   40.7145     7211212   -73.9425  5ba989232d0489da1b5f2c45f6688adc
# 15   40.7439     7225292   -73.9743  2c3b41f588fbb5234d8a1e885a436cfa
#
#                                                photos  price  \
# 4   [https://photos.renthop.com/2/7170325_3bb5ac84...   2400
# 6   [https://photos.renthop.com/2/7092344_7663c19a...   3800
# 9   [https://photos.renthop.com/2/7158677_c897a134...   3495
# 10  [https://photos.renthop.com/2/7211212_1ed4542e...   3000
# 15  [https://photos.renthop.com/2/7225292_901f1984...   2795
#
#              street_address interest_level  \
# 4       145 Borinquen Place         medium
# 6             230 East 44th            low
# 9      405 East 56th Street         medium
# 10  792 Metropolitan Avenue         medium
# 15     340 East 34th Street            low
#
#                                 truncated_description  \
# 4   spacious 1 bedroom 1 bathroom in williamsburg!...
# 6   brand new gut renovated true 2 bedroomfind you...
# 9   * * flex 2 bedroom with full pressurized wall ...
# 10  a brand new 3 bedroom 1. 5 bath apartmentenjoy...
# 15  over - sized studio w abundant closets. availa...
#
#                                             sentiment  sentiment_label
# 4   {'label': 'POSITIVE', 'score': 0.8850623965263...                1
# 6   {'label': 'POSITIVE', 'score': 0.998374342918396}                1
# 9   {'label': 'POSITIVE', 'score': 0.9986716508865...                1
# 10  {'label': 'NEGATIVE', 'score': 0.6298896074295...                0
# 15  {'label': 'NEGATIVE', 'score': 0.9978052973747...                0
